# %% [markdown]
# $$
# \begin{aligned}
# \hat{c}_{i t}^s & =\hat{w}_{i t}^{\beta_i^s} \prod_{k=1}^S\left(\hat{P}_{i t}^{k m *}\right)^{\beta_i^{s k}} \\
# \left(\hat{P}_{n t}^{s u *}\right)^{-\theta^s} & =\sum_{h=1}^N \pi_{n h 0}^{s u} \hat{\Lambda}_{h t}^s\left(\hat{c}_{h t}^s \hat{d}_{n h t}^{s u}\right)^{-\theta^s} \\
# \hat{\pi}_{n i t}^{s u} & =\frac{\hat{\Lambda}_{i t}^s\left(\hat{c}_{i t}^s \hat{d}_{n i t}^{s u}\right)^{-\theta^s}}{\left(\hat{P}_{n t}^{s u *}\right)^{-\theta^s}} \\
# X_{n t}^{s f \prime} & =\alpha_n^s\left[\hat{w}_{n t} \hat{L}_{n t} w_{n 0} L_{n 0}+\sum_{s=1}^S \sum_{i=1}^N \frac{\tau_{n i t}^{s \prime}}{1+\tau_{n i t}^{s \prime}}\left(\pi_{n i t}^{s f \prime} X_{n t}^{s f \prime}+\pi_{n i t}^{s m \prime} X_{n t}^{s m \prime}\right)+T D_{n t}^{\prime}\right] \\
# X_{n t}^{s m \prime} & =\sum_{k=1}^S \beta_n^{k s}\left(\sum_{i=1}^N \frac{\pi_{i n t}^{k f \prime}}{1+\tau_{i n t}^{k \prime \prime}} X_{i t}^{k f \prime}+\sum_{i=1}^N \frac{\pi_{i n t}^{k m \prime}}{1+\tau_{i n t}^{k \prime}} X_{i t}^{k m \prime}\right) \\
# T D_{n t}^{\prime} & =\sum_{s=1}^S \sum_{i=1}^N\left(\frac{\pi_{n i t}^{s f \prime} X_{n t}^{s f \prime}+\pi_{n i t}^{s m \prime} X_{n t}^{s m \prime}}{1+\tau_{n i t}^{s \prime}}-\frac{\pi_{i n t}^{s f \prime} X_{i t}^{s f \prime}+\pi_{i n t}^{s m \prime} X_{i t}^{s m \prime}}{1+\tau_{i n t}^{s \prime}}\right) \\
# \frac{T D_{n t}^{\prime}}{\sum_i \hat{w}_{i t} \hat{L}_{i t} w_{i 0} L_{i 0}} & =\frac{T D_{n 0}}{\sum_i w_{i 0} L_{i 0}}
# \end{aligned}
# $$

# %% [markdown]
# To rewrite and some changes in notation, we first clarify that for the shape $(N, N, S, S)$, and corresponding index is $(i, n, s, k)$ with the meaning $(\text{import country, export country, input sector, output sector})$.

# %% [markdown]
# $$
# \begin{aligned}
# \hat{c}_{is} & = \hat{w}_{i}^{\beta_{is}} \prod_{k=1}^S\left(\hat{P}_{ik}^{m}\right)^{\gamma_{isk}} &&(E1)\\[10pt]
#
# \left(\hat{P}_{is}^{u}\right)^{-\theta^s} & = \sum_{n=1}^N \pi_{i n s}^{0u} \hat{\Lambda}_{ns}\left(\hat{c}_{ns} \hat{d}_{ins}^u\right)^{-\theta^s} &&(E2)\\[10pt]
#
# \hat{\pi}_{i n s}^{u} & = \frac{\hat{\Lambda}_{ns}\left(\hat{c}_{ns} \hat{d}_{ins}^{u}\right)^{-\theta^s}}{\left(\hat{P}_{is}^{u}\right)^{-\theta^s}} &&(E3)\\[10pt]
#
# X_{is}^{f \prime} & = \alpha_{is}\left[\hat{w}_{i} V_i+\sum_{k=1}^S \sum_{n=1}^N \frac{\tau_{i n k}^{\prime}}{1+\tau_{i n k}^{\prime}}\left(\pi_{i n k}^{f \prime} X_{ik}^{f \prime}+\pi_{ink}^{m \prime} X_{ik}^{m \prime}\right)+D_{i}^{\prime}\right] &&(E4)\\[10pt]
#
# X_{is}^{m \prime} & = \sum_{k=1}^S \gamma_{iks}\left(\sum_{n=1}^N \frac{\pi_{n i k}^{f \prime}}{1+\tau_{n i k}^{\prime}} X_{n k}^{f \prime}+\sum_{n=1}^N \frac{\pi_{n i k}^{m \prime}}{1+\tau_{n i k}^{\prime}} X_{n k}^{m \prime}\right) &&(E5)\\[10pt]
#
# D_{i}^{\prime} & = \sum_{s=1}^S \sum_{n=1}^N\left(\frac{\pi_{ins}^{f \prime} X_{is}^{f \prime}+\pi_{ins}^{m \prime} X_{is}^{m \prime}}{1+\tau_{ins}^{\prime}}-\frac{\pi_{nis}^{f \prime} X_{ns}^{f \prime}+\pi_{nis}^{m \prime} X_{ns}^{m \prime}}{1+\tau_{nis}^{\prime}}\right) &&(E6)\\[10pt]
#
# \frac{D_{n}^{\prime}}{\sum_{i=1}^N \hat{w}_{i} V_{i} } & = \frac{D_{n}}{\sum_{i=1}^N V_i} &&(E7)
# \end{aligned}
# $$

# %% [markdown]
# ### Stacking convention
#
# $$
# \mathbf{x}^{f}=\operatorname{vec}(X^{f}),\qquad
# \mathbf{x}^{m}=\operatorname{vec}(X^{m}),\qquad
# \mathbf{d}=D.
# $$
#
#
# ### Blockwise linear system
#
# $$
# \underbrace{\begin{bmatrix}
# \mathbf{x}^{f}\\[2pt] \mathbf{x}^{m}\\[2pt] \mathbf{d}
# \end{bmatrix}}_{\mathbf{X}}
# =
# \underbrace{\begin{bmatrix}
# \mathbf{a}^{f}\\[2pt] \mathbf{0}\\[2pt] \mathbf{0}
# \end{bmatrix}}_{\mathbf{A}}
# +
# \underbrace{\begin{bmatrix}
# B_{ff} & B_{fm} & B_{fD}\\
# B_{mf} & B_{mm} & 0\\
# B_{Df} & B_{Dm} & 0
# \end{bmatrix}}_{B}\,
# \mathbf{X},
# \qquad
# (I-B)\,\mathbf{X}=\mathbf{A}.
# $$
#
#
#
# ### Building blocks
#
# $$
# \mathbf{A}^{f}_{is}= \alpha_{is}\,\hat w_i V_i,
# \qquad
# \mathbf{a}^{f}= \operatorname{vec}\bigl(\mathbf{A}^{f}\bigr).
# $$
#
# #### Cross-sector weights
# $$
# \lambda^{ff}_{isk}= \sum_{n=1}^{N}
#       \frac{\tau'_{ink}}{1+\tau'_{ink}}\,
#       \pi^{f'}_{ink},
# \qquad
# \lambda^{fm}_{isk}= \sum_{n=1}^{N}
#       \frac{\tau'_{ink}}{1+\tau'_{ink}}\,
#       \pi^{m'}_{ink}.
# $$
#
# #### Final-goods block (country-wise block diagonal, full within country)
# For each country \(i\) let
# $$
# (\Lambda^{ff}_{i})_{s k}= \alpha_{is}\,\lambda^{ff}_{isk},
# \qquad
# (\Lambda^{fm}_{i})_{s k}= \alpha_{is}\,\lambda^{fm}_{isk}.
# $$
#
# $$
# B_{ff}= \operatorname{blockdiag}\bigl(\Lambda^{ff}_{1},\dots,\Lambda^{ff}_{N}\bigr),
# \qquad
# B_{fm}= \operatorname{blockdiag}\bigl(\Lambda^{fm}_{1},\dots,\Lambda^{fm}_{N}\bigr).
# $$
#
# #### Link to trade balance
# $$
# B_{fD}= \operatorname{diag}(\alpha_{is})\,(\mathbf 1_{S}\!\otimes\! I_{N}).
# $$
#
# #### Intermediate-goods blocks
# $$
# \bigl[B_{mf}\bigr]_{(i,s),(n,k)}=
#       \gamma_{isk}\,
#       \frac{\pi^{f'}_{ink}}{1+\tau'_{ink}},
# \qquad
# \bigl[B_{mm}\bigr]_{(i,s),(n,k)}=
#       \gamma_{isk}\,
#       \frac{\pi^{m'}_{ink}}{1+\tau'_{ink}}.
# $$
#
# #### Trade-balance rows
# $$
# \begin{aligned}
# \bigl[B_{Df}\bigr]_{\,i,(n,s)} &=
#       \frac{\pi^{f'}_{ins}}{1+\tau'_{ins}}
#     - \frac{\pi^{f'}_{nis}}{1+\tau'_{nis}},\\[4pt]
# \bigl[B_{Dm}\bigr]_{\,i,(n,s)} &=
#       \frac{\pi^{m'}_{ins}}{1+\tau'_{ins}}
#     - \frac{\pi^{m'}_{nis}}{1+\tau'_{nis}}.
# \end{aligned}
# $$

# %% [markdown]
# For the quadratic matrix equation
#
# $$
# X \;=\; A \;+\; B\,X\,C ,
# $$
#
# vectorising with **vec** and Kronecker products gives
#
# $$
# \bigl[I - (C^{\!\top}\!\otimes B)\bigr]\,
# \operatorname{vec}(X)
# \;=\;
# \operatorname{vec}(A).
# $$
#
# ---
#
# ### Closed-form solution
#
# $$
# \boxed{\;
# X \;=\; \operatorname{vec}^{-1}\!
#         \Bigl(
#           \bigl[I - (C^{\!\top}\!\otimes B)\bigr]^{-1}
#           \operatorname{vec}(A)
#         \Bigr)}
# $$
#
# provided that
# $$
# \det\!\bigl[I - (C^{\!\top}\!\otimes B)\bigr] \neq 0
# \quad\Longleftrightarrow\quad
# \rho(B)\,\rho(C) < 1 .
# $$
#
# $\rho(B)\rho(C)<1$ the same solution is reached by the convergent
# fixed-point iteration $X_{t+1}=A+BX_tC$.

# %% [markdown]
# # Linear System Transformation

# %% [markdown]
# $$
# \begin{aligned}
# \hat{c}_{is} & = \hat{w}_{i}^{\beta_{is}} \prod_{k=1}^S\left(\hat{P}_{ik}^{m}\right)^{\gamma_{isk}} &&(E1)\\[10pt]
#
# \left(\hat{P}_{is}^{u}\right)^{-\theta^s} & = \sum_{n=1}^N \pi_{i n s}^{0u} \hat{\Lambda}_{ns}\left(\hat{c}_{ns} \hat{d}_{ins}^u\right)^{-\theta^s} &&(E2)\\[10pt]
#
# \hat{\pi}_{i n s}^{u} & = \frac{\hat{\Lambda}_{ns}\left(\hat{c}_{ns} \hat{d}_{ins}^{u}\right)^{-\theta^s}}{\left(\hat{P}_{is}^{u}\right)^{-\theta^s}} &&(E3)\\[10pt]
#
# X_{is}^{f \prime} & = \alpha_{is}\left[\hat{w}_{i} V_i+\sum_{k=1}^S \sum_{n=1}^N \frac{\tau_{i n k}^{\prime}}{1+\tau_{i n k}^{\prime}}\left(\pi_{i n k}^{f \prime} X_{ik}^{f \prime}+\pi_{ink}^{m \prime} X_{ik}^{m \prime}\right)+D_{i}^{\prime}\right] &&(E4)\\[10pt]
#
# X_{is}^{m \prime} & = \sum_{k=1}^S \gamma_{iks}\left(\sum_{n=1}^N \frac{\pi_{n i k}^{f \prime}}{1+\tau_{n i k}^{\prime}} X_{n k}^{f \prime}+\sum_{n=1}^N \frac{\pi_{n i k}^{m \prime}}{1+\tau_{n i k}^{\prime}} X_{n k}^{m \prime}\right) &&(E5)\\[10pt]
#
# D_{i}^{\prime} & = \sum_{s=1}^S \sum_{n=1}^N\frac{\pi_{ins}^{f \prime} X_{is}^{f \prime}+\pi_{ins}^{m \prime} X_{is}^{m \prime}}{1+\tau_{ins}^{\prime}}- \sum_{s=1}^S \sum_{i=1}^N\frac{\pi_{ins}^{f \prime} X_{is}^{f \prime}+\pi_{ins}^{m \prime} X_{is}^{m \prime}}{1+\tau_{ins}^{\prime}} &&(E6)\\[10pt]
#
# \frac{D_{n}^{\prime}}{\sum_{i=1}^N \hat{w}_{i} V_{i} } & = \frac{D_{n}}{\sum_{i=1}^N V_i} &&(E7)
# \end{aligned}
# $$

# %% [markdown]
# $$
# \begin{aligned}
# X_{is}^{\prime}&=\sum_{k=1}^S \gamma_{iks} \sum_{n=1}^N \frac{\pi_{nik}^{\prime}}{1+\tau_{nik}^{\prime}} X_{nk}^{\prime}+\alpha_{is} \left[\hat{w}_{i} V_i+\sum_{k=1}^S \sum_{n=1}^N \frac{\tau_{i n k}^{\prime}}{1+\tau_{i n k}^{\prime}}\pi_{i n k}^{\prime} X_{ik}^{\prime}+D_{i}\right]\\
#
# D_i^{\prime}&=\sum_{s=1}^S \sum_{n=1}^N \frac{\pi_{i n s}^{ \prime}}{1+\tau_{ins}^{\prime}} X_{is}^{\prime} - \sum_{s=1}^S \sum_{i=1}^N \frac{\pi_{ins}^{\prime}}{1+\tau_{ins}^{\prime}} X_{is}^{\prime}
# \end{aligned}
# $$

# %% [markdown]
# ## Derivation of Linear System (Caliendo and Parro, 2015)
#
# *(Notation explicitly: importer $n$, exporter $i$, sectors $s,k$, total sectors $S$.)*
#
# ---
#
# ### Step 1: Original Scalar Equation
#
# The equilibrium scalar equation explicitly adapted from CP2015 is:
#
# $$
# X_{ns}'
# = \sum_{k=1}^{S}\gamma_{nsk}\sum_{i=1}^{N}\frac{\pi_{nik}'}{1+\tau_{nik}'}X_{ik}'
# + \alpha_{ns}\left[\hat{w}_nV_n + \sum_{k=1}^{S}\sum_{i=1}^{N}\frac{\tau_{nik}'\pi_{nik}'}{1+\tau_{nik}'}X_{nk}' + D_n\right]
# $$
#
# Explicit definitions:
#
# - $X_{ns}'$: total expenditure by importer country $n$ on goods in sector $s$.
# - $\pi_{nik}'$: trade share from exporter $i$ (sector $k$) to importer $n$.
# - $\tau_{nik}'$: tariff from exporter $i$ (sector $k$) to importer $n$.
# - $\gamma_{nsk}$: input-output coefficients for importer $n$, from input sector $k$ into output sector $s$.
# - $\alpha_{ns}$: value-added share in importer $n$, sector $s$.
#
# ---
#
# ### Step 2: Explicit Separation of Exogenous Terms
#
# Clearly define the exogenous terms as:
#
# $$
# A_{ns} = \alpha_{ns}(\hat{w}_nV_n + D_n)
# $$
#
# Thus, explicitly rewriting the scalar equation:
#
# $$
# X_{ns}' = A_{ns}
# + \sum_{k=1}^{S}\sum_{i=1}^{N}\gamma_{nsk}\frac{\pi_{nik}'}{1+\tau_{nik}'}X_{ik}'
# + \alpha_{ns}\sum_{k=1}^{S}\sum_{i=1}^{N}\frac{\tau_{nik}'\pi_{nik}'}{1+\tau_{nik}'}X_{nk}'
# $$
#
# ---
#
# ### Step 3: Explicit Definition of Vectorization
#
# Explicitly define the vectorization operator $vec(X')$, stacking columns sector-by-sector clearly as:
#
# $$
# vec(X') = [X'_{11}, X'_{21}, \dots, X'_{N1}, X'_{12}, X'_{22}, \dots, X'_{N2}, \dots, X'_{1S}, \dots, X'_{NS}]'
# $$
#
# Clearly, $vec(X')$ and $vec(A)$ are $(NS\times 1)$ vectors.
#
# ---
#
# ### Step 4: Explicit Matrix Form ($vec(X') = vec(A) + B\,vec(X')$)
#
# We explicitly form the vectorized linear algebra equation as:
#
# $$
# vec(X') = vec(A) + B\,vec(X')
# $$
#
# Clearly rewrite the scalar equation explicitly with indices:
#
# $$
# X_{ns}' = A_{ns}
# + \sum_{i=1}^{N}\sum_{k=1}^{S}\gamma_{nsk}\frac{\pi_{nik}'}{1+\tau_{nik}'}X_{ik}'
# + \sum_{i=1}^{N}\sum_{k=1}^{S}\alpha_{ns}\frac{\tau_{nik}'\pi_{nik}'}{1+\tau_{nik}'}X_{nk}'
# $$
#
# ---
#
# ### Step 5: Explicit Construction of Matrix $B$
#
# Matrix $B$ explicitly has dimensions $(NS\times NS)$, clearly indexed by rows $(ns)$ and columns $(ik)$ matching vectorization order:
#
# $$
# B_{(ns)(ik)}
# = \gamma_{nsk}\frac{\pi_{nik}'}{1+\tau_{nik}'}
# + \mathbf{1}(n=i)\cdot\alpha_{ns}\frac{\tau_{nik}'\pi_{nik}'}{1+\tau_{nik}'}
# $$
#
# Explicit explanation:
#
# - First term explicitly captures input-output linkages and trade flows from exporter $i$ to importer $n$ across sectors.
# - Second term (indicator $\mathbf{1}(n=i)$) explicitly captures importer's own tariff expenditures.
#
# ---
#
# ### Step 6: Final Explicit Linear Algebra Form
#
# The explicit vectorized linear algebra form is:
#
# $$
# vec(X') = vec(A) + B\,vec(X')
# $$
#
# Explicitly isolating the endogenous variable:
#
# $$
# (I - B)\,vec(X') = vec(A)
# $$
#
# - Dimensions explicitly stated:
#   - $vec(X')$, $vec(A)$: $(NS\times 1)$ vectors.
#   - $B$: $(NS\times NS)$ matrix explicitly defined.
#   - $I$: $(NS\times NS)$ identity matrix.
#
# ---
#
# ### Step 7: Explicit Final Solution
#
# Thus, explicitly, the equilibrium solution (fully consistent with CP2015) is clearly stated as:
#
# $$
# \boxed{vec(X') = (I - B)^{-1} vec(A)}
# $$
#
# This explicitly matches Caliendo and Parro (2015), clearly adapted to your desired indexing, explicitly ready for computational implementation.
#
# ---
